# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading and describing data

# %%
user_profile_df = pd.read_csv('user_profile.csv')
user_profile_df.columns = user_profile_df.columns.str.strip()

# %%
user_profile_df.describe()
# Out:
#              userid     cms_segid  cms_group_id  final_gender_code  \
# count  1.061768e+06  1.061768e+06  1.061768e+06       1.061768e+06
# mean   5.713104e+05  1.512998e+01  5.542412e+00       1.644445e+00
# std    3.295021e+05  2.535503e+01  3.178516e+00       4.786814e-01
# min    1.000000e+00  0.000000e+00  0.000000e+00       1.000000e+00
# 25%    2.862458e+05  0.000000e+00  3.000000e+00       1.000000e+00
# 50%    5.714555e+05  0.000000e+00  4.000000e+00       2.000000e+00
# 75%    8.546662e+05  2.000000e+01  9.000000e+00       2.000000e+00
# max    1.141729e+06  9.600000e+01  1.200000e+01       2.000000e+00
#
#           age_level   pvalue_level  shopping_level    occupation  \
# count  1.061768e+06  485851.000000    1.061768e+06  1.061768e+06
# mean   3.410641e+00       1.759850    2.716854e+00  5.623074e-02
# std    1.227458e+00       0.581303    5.861036e-01  2.303669e-01
# min    0.000000e+00       1.000000    1.000000e+00  0.000000e+00
# 25%    3.000000e+00       1.000000    3.000000e+00  0.000000e+00
# 50%    3.000000e+00       2.000000    3.000000e+00  0.000000e+00
# 75%    4.000000e+00       2.000000    3.000000e+00  0.000000e+00
# max    6.000000e+00       3.000000    3.000000e+00  1.000000e+00
#
#        new_user_class_level
# count         716848.000000
# mean               2.516379
# std                0.928334
# min                1.000000
# 25%                2.000000
# 50%                2.000000
# 75%                3.000000
# max                4.000000

# %%
user_profile_df.head()
# Out:
#    userid  cms_segid  cms_group_id  final_gender_code  age_level  \
# 0     234          0             5                  2          5
# 1     523          5             2                  2          2
# 2     612          0             8                  1          2
# 3    1670          0             4                  2          4
# 4    2545          0            10                  1          4
#
#    pvalue_level  shopping_level  occupation  new_user_class_level
# 0           NaN               3           0                   3.0
# 1           1.0               3           1                   2.0
# 2           2.0               3           0                   NaN
# 3           NaN               1           0                   NaN
# 4           NaN               3           0                   NaN

# %%
user_profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061768 entries, 0 to 1061767
# Data columns (total 9 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   userid                1061768 non-null  int64
#  1   cms_segid             1061768 non-null  int64
#  2   cms_group_id          1061768 non-null  int64
#  3   final_gender_code     1061768 non-null  int64
#  4   age_level             1061768 non-null  int64
#  5   pvalue_level          485851 non-null   float64
#  6   shopping_level        1061768 non-null  int64
#  7   occupation            1061768 non-null  int64
#  8   new_user_class_level  716848 non-null   float64
# dtypes: float64(2), int64(7)
# memory usage: 72.9 MB

# %%
print(user_profile_df.isnull().sum())
# Out:
# userid                       0
# cms_segid                    0
# cms_group_id                 0
# final_gender_code            0
# age_level                    0
# pvalue_level            575917
# shopping_level               0
# occupation                   0
# new_user_class_level    344920
# dtype: int64

# %%
for col in user_profile_df.columns:
    if user_profile_df[col].isnull().any():
        unique_vals = user_profile_df[col].unique()
        print(f"Column: {col}")
        print(f"Unique Values (including NaN): {unique_vals}\n")
# Out:
# Column: pvalue_level
# Unique Values (including NaN): [nan  1.  2.  3.]
#
# Column: new_user_class_level
# Unique Values (including NaN): [ 3.  2. nan  4.  1.]

# %%
import faiss
import numpy as np
import pandas as pd

features = ['cms_segid', 'cms_group_id', 'final_gender_code', 'age_level', 'shopping_level', 'occupation']
columns_to_fill = ['pvalue_level', 'new_user_class_level']

for col in features:
    user_profile_df[col] = pd.to_numeric(user_profile_df[col], downcast='unsigned')

for column in columns_to_fill:
    missing_df = user_profile_df[user_profile_df[column].isnull()]
    non_missing_df = user_profile_df[user_profile_df[column].notnull()]

    X = non_missing_df[features].values.astype(np.float32)
    y = non_missing_df[column].values
    X_missing = missing_df[features].values.astype(np.float32)

    index = faiss.IndexFlatL2(X.shape[1])

    index.add(X)

    batch_size = 10000
    num_batches = int(np.ceil(len(X_missing) / batch_size))
    missing_indices = missing_df.index.to_numpy()

    for i in range(num_batches):
        start = i * batch_size
        end = min((i + 1) * batch_size, len(X_missing))

        X_batch = X_missing[start:end]
        
        distances, indices = index.search(X_batch, k=1)

        predicted_vals = y[indices.flatten()]
        
        user_profile_df.loc[missing_indices[start:end], column] = predicted_vals

        print(f"Filled batch {i+1}/{num_batches} for column: {column}")

print("Missing brand values filled using FAISS with Euclidean similarity.")
# Out:
# Filled batch 1/58 for column: pvalue_level
# Filled batch 2/58 for column: pvalue_level
# Filled batch 3/58 for column: pvalue_level
# Filled batch 4/58 for column: pvalue_level
# Filled batch 5/58 for column: pvalue_level
# Filled batch 6/58 for column: pvalue_level
# Filled batch 7/58 for column: pvalue_level
# Filled batch 8/58 for column: pvalue_level
# Filled batch 9/58 for column: pvalue_level
# Filled batch 10/58 for column: pvalue_level
# Filled batch 11/58 for column: pvalue_level
# Filled batch 12/58 for column: pvalue_level
# Filled batch 13/58 for column: pvalue_level
# Filled batch 14/58 for column: pvalue_level
# Filled batch 15/58 for column: pvalue_level
# Filled batch 16/58 for column: pvalue_level
# Filled batch 17/58 for column: pvalue_level
# Filled batch 18/58 for column: pvalue_level
# Filled batch 19/58 for column: pvalue_level
# Filled batch 20/58 for column: pvalue_level
# Filled batch 21/58 for column: pvalue_level
# Filled batch 22/58 for column: pvalue_level
# Filled batch 23/58 for column: pvalue_level
# Filled batch 24/58 for column: pvalue_level
# Filled batch 25/58 for column: pvalue_level
# Filled batch 26/58 for column: pvalue_level
# Filled batch 27/58 for column: pvalue_level
# Filled batch 28/58 for column: pvalue_level
# Filled batch 29/58 for column: pvalue_level
# Filled batch 30/58 for column: pvalue_level
# Filled batch 31/58 for column: pvalue_level
# Filled batch 32/58 for column: pvalue_level
# Filled batch 33/58 for column: pvalue_level
# Filled batch 34/58 for column: pvalue_level
# Filled batch 35/58 for column: pvalue_level
# Filled batch 36/58 for column: pvalue_level
# Filled batch 37/58 for column: pvalue_level
# Filled batch 38/58 for column: pvalue_level
# Filled batch 39/58 for column: pvalue_level
# Filled batch 40/58 for column: pvalue_level
# Filled batch 41/58 for column: pvalue_level
# Filled batch 42/58 for column: pvalue_level
# Filled batch 43/58 for column: pvalue_level
# Filled batch 44/58 for column: pvalue_level
# Filled batch 45/58 for column: pvalue_level
# Filled batch 46/58 for column: pvalue_level
# Filled batch 47/58 for column: pvalue_level
# Filled batch 48/58 for column: pvalue_level
# Filled batch 49/58 for column: pvalue_level
# Filled batch 50/58 for column: pvalue_level
# Filled batch 51/58 for column: pvalue_level
# Filled batch 52/58 for column: pvalue_level
# Filled batch 53/58 for column: pvalue_level
# Filled batch 54/58 for column: pvalue_level
# Filled batch 55/58 for column: pvalue_level
# Filled batch 56/58 for column: pvalue_level
# Filled batch 57/58 for column: pvalue_level
# Filled batch 58/58 for column: pvalue_level
# Filled batch 1/35 for column: new_user_class_level
# Filled batch 2/35 for column: new_user_class_level
# Filled batch 3/35 for column: new_user_class_level
# Filled batch 4/35 for column: new_user_class_level
# Filled batch 5/35 for column: new_user_class_level
# Filled batch 6/35 for column: new_user_class_level
# Filled batch 7/35 for column: new_user_class_level
# Filled batch 8/35 for column: new_user_class_level
# Filled batch 9/35 for column: new_user_class_level
# Filled batch 10/35 for column: new_user_class_level
# Filled batch 11/35 for column: new_user_class_level
# Filled batch 12/35 for column: new_user_class_level
# Filled batch 13/35 for column: new_user_class_level
# Filled batch 14/35 for column: new_user_class_level
# Filled batch 15/35 for column: new_user_class_level
# Filled batch 16/35 for column: new_user_class_level
# Filled batch 17/35 for column: new_user_class_level
# Filled batch 18/35 for column: new_user_class_level
# Filled batch 19/35 for column: new_user_class_level
# Filled batch 20/35 for column: new_user_class_level
# Filled batch 21/35 for column: new_user_class_level
# Filled batch 22/35 for column: new_user_class_level
# Filled batch 23/35 for column: new_user_class_level
# Filled batch 24/35 for column: new_user_class_level
# Filled batch 25/35 for column: new_user_class_level
# Filled batch 26/35 for column: new_user_class_level
# Filled batch 27/35 for column: new_user_class_level
# Filled batch 28/35 for column: new_user_class_level
# Filled batch 29/35 for column: new_user_class_level
# Filled batch 30/35 for column: new_user_class_level
# Filled batch 31/35 for column: new_user_class_level
# Filled batch 32/35 for column: new_user_class_level
# Filled batch 33/35 for column: new_user_class_level
# Filled batch 34/35 for column: new_user_class_level
# Filled batch 35/35 for column: new_user_class_level
# Missing brand values filled using FAISS with Euclidean similarity.

# %%
duplicate_count = user_profile_df.duplicated(subset='userid').sum()
print(f"Number of duplicate user IDs: {duplicate_count}")
# Out:
# Number of duplicate user IDs: 0

# %%
user_profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061768 entries, 0 to 1061767
# Data columns (total 9 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   userid                1061768 non-null  int64
#  1   cms_segid             1061768 non-null  uint8
#  2   cms_group_id          1061768 non-null  uint8
#  3   final_gender_code     1061768 non-null  uint8
#  4   age_level             1061768 non-null  uint8
#  5   pvalue_level          1061768 non-null  float64
#  6   shopping_level        1061768 non-null  uint8
#  7   occupation            1061768 non-null  uint8
#  8   new_user_class_level  1061768 non-null  float64
# dtypes: float64(2), int64(1), uint8(6)
# memory usage: 30.4 MB

# %%
import os
os.makedirs('preprocessed', exist_ok=True)
user_profile_df.to_csv('preprocessed/user_profile_final.csv', index=False)
